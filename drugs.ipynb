# %%
import requests
import pandas as pd

# API endpoint
url = "https://api.fda.gov/drug/label.json?limit=100"  # limit = number of records per request

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    results = data['results']

    # Extract some useful fields for your portfolio
    records = []
    for item in results:
        record = {
            "brand_name": item.get("openfda", {}).get("brand_name", [""])[0],
            "generic_name": item.get("openfda", {}).get("generic_name", [""])[0],
            "manufacturer_name": item.get("openfda", {}).get("manufacturer_name", [""])[0],
            "adverse_reactions": item.get("adverse_reactions", [""])[0] if "adverse_reactions" in item else "",
            "indications_and_usage": item.get("indications_and_usage", [""])[0] if "indications_and_usage" in item else ""
        }
        records.append(record)

    # Convert to DataFrame
    df = pd.DataFrame(records)

    # Save to CSV
    df.to_csv("drug_data.csv", index=False)
    print("Data saved to drug_data.csv")

else:
    print("Failed to retrieve data:", response.status_code)
# Out:
# Data saved to drug_data.csv

# %%
import pandas as pd

# %%
data=pd.read_csv("drug_data.csv")

# %%
data.head()
# Out:
#   brand_name     generic_name                            manufacturer_name  \
# 0    SILICEA          SILICEA  Rxhomeo Private Limited d.b.a. Rxhomeo, Inc
# 1        NaN              NaN                                          NaN
# 2   Betadine  POVIDONE-IODINE           Atlantis Consumer Healthcare, Inc.
# 3        NaN              NaN                                          NaN
# 4        NaN              NaN                                          NaN
#
#                                    adverse_reactions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  ADVERSE REACTIONS Ophthalmic use: The most fre...
#
#                                indications_and_usage
# 0  INDICATIONS Condition listed above or as direc...
# 1  Uses Multi-purpose mineral powder provides bro...
# 2  Uses First aid to help prevent infection in mi...
# 3          INDICATIONS Indications: MEZEREUM Itching
# 4  INDICATIONS AND USAGE Ofloxacin ophthalmic sol...

# %%
data.dropna()
# Out:
#                     brand_name                 generic_name  \
# 5                     Naproxen                     NAPROXEN
# 10                Quick Action               SALICYLIC ACID
# 12                    Mekinist                   TRAMETINIB
# 14                 Glimepiride                  GLIMEPIRIDE
# 16               Methocarbamol                METHOCARBAMOL
# 18              NP Thyroid 120  LEVOTHYROXINE, LIOTHYRONINE
# 19                 Varenicline                  VARENICLINE
# 41  Betamethasone Dipropionate   BETAMETHASONE DIPROPIONATE
# 45             Calcium Acetate              CALCIUM ACETATE
# 49                    ENTRESTO     SACUBITRIL AND VALSARTAN
# 60                    Etodolac                     ETODOLAC
# 68            Anticavity Rinse              SODIUM FLUORIDE
# 69    Sertraline Hydrochloride     SERTRALINE HYDROCHLORIDE
# 90                  Dronabinol                   DRONABINOL
# 98     Fludrocortisone Acetate      FLUDROCORTISONE ACETATE
#
#                        manufacturer_name  \
# 5               A-S Medication Solutions
# 10                          Walmart Inc.
# 12  Novartis Pharmaceuticals Corporation
# 14             American Health Packaging
# 16                      Proficient Rx LP
# 18           Acella Pharmaceuticals, LLC
# 19              Aurobindo Pharma Limited
# 41   Sun Pharmaceutical Industries, Inc.
# 45                       Cipla USA Inc.,
# 49  Novartis Pharmaceuticals Corporation
# 60              A-S Medication Solutions
# 68             Meijer Distribution, Inc.
# 69                      Proficient Rx LP
# 90                  Bryant Ranch Prepack
# 98             American Health Packaging
#
#                                     adverse_reactions  \
# 5   6 ADVERSE REACTIONS The following adverse reac...
# 10  ADVERSE REACTION DISTRIBUTED BY: Wal-Mart Stor...
# 12  6 ADVERSE REACTIONS The following clinically s...
# 14  6 ADVERSE REACTIONS The following serious adve...
# 16  ADVERSE REACTIONS Adverse reactions reported c...
# 18  ADVERSE REACTIONS Adverse reactions other than...
# 19  6 ADVERSE REACTIONS The following serious adve...
# 41  6 ADVERSE REACTIONS The most common adverse re...
# 45  6 ADVERSE REACTIONS Hypercalcemia is discussed...
# 49  6 ADVERSE REACTIONS Clinically significant adv...
# 60  ADVERSE REACTIONS In patients taking etodolac ...
# 68  Adverse reactions Distributed By Meijer Distri...
# 69  ADVERSE REACTIONS During its premarketing asse...
# 90  6 ADVERSE REACTIONS Most common adverse reacti...
# 98  ADVERSE REACTIONS Most adverse reactions are c...
#
#                                 indications_and_usage
# 5   1 INDICATIONS AND USAGE Naproxen tablets and n...
# 10                     Uses for the treatment of acne
# 12  1 INDICATIONS AND USAGE MEKINIST is a kinase i...
# 14  1 INDICATIONS AND USAGE Glimepiride tablets ar...
# 16  INDICATIONS AND USAGE Methocarbamol tablets, U...
# 18  INDICATIONS AND USAGE NP Thyroid ® tablets (th...
# 19  1 INDICATIONS AND USAGE Varenicline tablets ar...
# 41  1 INDICATIONS AND USAGE Betamethasone dipropio...
# 45  1 INDICATIONS AND USAGE Calcium acetate is a p...
# 49  1 INDICATIONS AND USAGE ENTRESTO is a combinat...
# 60  INDICATIONS AND USAGE Carefully consider the p...
# 68      Use aids in the prevention of dental cavities
# 69  INDICATIONS AND USAGE Major Depressive Disorde...
# 90  1 INDICATIONS AND USAGE Dronabinol capsules ar...
# 98  INDICATIONS AND USAGE Fludrocortisone acetate ...

# %%
new_1 = data.drop(["brand_name"],axis=1)

# %%
new_1.dropna()
# Out:
#                    generic_name                     manufacturer_name  \
# 5                      NAPROXEN              A-S Medication Solutions
# 10               SALICYLIC ACID                          Walmart Inc.
# 12                   TRAMETINIB  Novartis Pharmaceuticals Corporation
# 14                  GLIMEPIRIDE             American Health Packaging
# 16                METHOCARBAMOL                      Proficient Rx LP
# 18  LEVOTHYROXINE, LIOTHYRONINE           Acella Pharmaceuticals, LLC
# 19                  VARENICLINE              Aurobindo Pharma Limited
# 41   BETAMETHASONE DIPROPIONATE   Sun Pharmaceutical Industries, Inc.
# 45              CALCIUM ACETATE                       Cipla USA Inc.,
# 49     SACUBITRIL AND VALSARTAN  Novartis Pharmaceuticals Corporation
# 60                     ETODOLAC              A-S Medication Solutions
# 68              SODIUM FLUORIDE             Meijer Distribution, Inc.
# 69     SERTRALINE HYDROCHLORIDE                      Proficient Rx LP
# 90                   DRONABINOL                  Bryant Ranch Prepack
# 98      FLUDROCORTISONE ACETATE             American Health Packaging
#
#                                     adverse_reactions  \
# 5   6 ADVERSE REACTIONS The following adverse reac...
# 10  ADVERSE REACTION DISTRIBUTED BY: Wal-Mart Stor...
# 12  6 ADVERSE REACTIONS The following clinically s...
# 14  6 ADVERSE REACTIONS The following serious adve...
# 16  ADVERSE REACTIONS Adverse reactions reported c...
# 18  ADVERSE REACTIONS Adverse reactions other than...
# 19  6 ADVERSE REACTIONS The following serious adve...
# 41  6 ADVERSE REACTIONS The most common adverse re...
# 45  6 ADVERSE REACTIONS Hypercalcemia is discussed...
# 49  6 ADVERSE REACTIONS Clinically significant adv...
# 60  ADVERSE REACTIONS In patients taking etodolac ...
# 68  Adverse reactions Distributed By Meijer Distri...
# 69  ADVERSE REACTIONS During its premarketing asse...
# 90  6 ADVERSE REACTIONS Most common adverse reacti...
# 98  ADVERSE REACTIONS Most adverse reactions are c...
#
#                                 indications_and_usage
# 5   1 INDICATIONS AND USAGE Naproxen tablets and n...
# 10                     Uses for the treatment of acne
# 12  1 INDICATIONS AND USAGE MEKINIST is a kinase i...
# 14  1 INDICATIONS AND USAGE Glimepiride tablets ar...
# 16  INDICATIONS AND USAGE Methocarbamol tablets, U...
# 18  INDICATIONS AND USAGE NP Thyroid ® tablets (th...
# 19  1 INDICATIONS AND USAGE Varenicline tablets ar...
# 41  1 INDICATIONS AND USAGE Betamethasone dipropio...
# 45  1 INDICATIONS AND USAGE Calcium acetate is a p...
# 49  1 INDICATIONS AND USAGE ENTRESTO is a combinat...
# 60  INDICATIONS AND USAGE Carefully consider the p...
# 68      Use aids in the prevention of dental cavities
# 69  INDICATIONS AND USAGE Major Depressive Disorde...
# 90  1 INDICATIONS AND USAGE Dronabinol capsules ar...
# 98  INDICATIONS AND USAGE Fludrocortisone acetate ...

# %%
import nltk

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Hi-
# [nltk_data]     TecH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
all_side_effects = ' '.join(new_1['adverse_reactions'].dropna().tolist())

# %%
words = all_side_effects.lower().replace(',',' ').split()

# %%
from collections import Counter

# %%
side_effect = Counter(words)

# %%
side_effect.most_common(5)
# Out:
# [('and', 965), ('in', 923), ('of', 904), ('the', 746), ('adverse', 479)]

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words("english"))
filtered = [w for w in words if w.lower() not in stop_words]
counts = Counter(filtered)

# %%
print(counts)
# Out:
# Counter({'adverse': 479, 'patients': 458, 'reactions': 355, 'events': 205, 'clinical': 186, 'reported': 182, '1': 166, 'trials': 162, '3': 145, 'pain': 141, '0': 134, 'increased': 126, 'system': 124, '–': 122, 'mekinist': 116, 'skin': 113, '2': 108, 'warnings': 105, 'rash': 104, '6': 102, 'incidence': 101, 'table': 98, '-': 98, 'precautions': 93, 'treatment': 93, 'placebo': 92, '4': 88, 'nausea': 87, 'observed': 85, '[see': 85, 'treated': 84, 'rare:': 83, '=': 82, 'following': 81, 'infrequent:': 79, 'disorder': 79, 'received': 77, 'dabrafenib': 76, '5': 75, '1%': 73, 'disorders': 73, 'reaction': 70, 'studies': 70, ')': 69, 'drug': 69, 'decreased': 69, 'study': 68, 'common': 67, 'occurred': 66, 'gastrointestinal': 64, 'abnormal': 64, 'edema': 63, 'abdominal': 62, 'diarrhea': 61, 'vomiting': 61, 'respiratory': 61, 'renal': 60, 'mg': 60, '(see': 60, 'hemorrhage': 59, '(%)': 59, '(': 58, 'bleeding': 57, 'nervous': 57, '10': 56, 'headache': 55, 'associated': 54, 'failure': 53, 'may': 53, '7': 53, '2%': 53, 'dizziness': 52, 'laboratory': 52, 'trial': 51, 'greater': 50, 'occurring': 49, 'event': 49, 'body': 48, 'rates': 48, 'system:': 48, 'therapy': 48, 'least': 48, 'dry': 47, '12': 47, 'discontinuation': 47, 'patients.': 46, 'includes': 45, 'sertraline': 45, 'grades': 44, 'compared': 43, 'controlled': 43, 'anemia': 43, 'pyrexia': 43, '8': 43, ']': 42, 'pediatric': 41, 'postmarketing': 41, 'peripheral': 41, 'years': 41, 'plus': 41, 'heart': 40, 'experience': 40, 'depression': 40, 'including': 40, 'dose': 40, 'frequent:': 40, 'syndrome': 39, '<': 39, '11': 39, 'frequency': 38, 'hypotension': 38, 'citalopram': 38, 'hypertension': 37, 'use': 37, 'fatigue': 37, '(n': 37, 'placebo-controlled': 37, 'disorders:': 37, 'frequent': 36, '.': 36, 'abnormalities': 35, 'anxiety': 35, '9': 35, '6.1': 34, 'relationship': 34, 'insomnia': 34, 'combination': 34, 'n': 34, 'hepatic': 34, 'due': 34, 'cardiovascular': 33, 'doses': 33, 'constipation': 33, 'musculoskeletal': 33, 'serious': 32, 'infection': 32, 'varenicline': 32, 'general': 31, 'daily': 31, 'less': 31, 'taking': 30, 'liver': 30, 'dermatitis': 30, 'serum': 30, 'age': 30, 'urinary': 30, 'group': 30, 'major': 30, 'hbr': 30, 'experiences': 29, 'disease': 29, 'dysfunction': 29, 'acute': 29, 'psychiatric': 29, 'loss': 29, 'eye': 28, 'mouth': 28, 'blood': 28, 'treatment-emergent': 28, 'included': 28, 'hypersensitivity': 28, 'allergic': 28, 'reports': 27, '3%': 27, 'weight': 27, 'exposed': 27, '18': 27, '>': 27, 'baseline': 27, 'rate': 27, 'hydrochloride': 27, 'listed': 26, ')]': 26, 'one': 26, '≥': 26, 'double-blind': 26, 'receiving': 26, 'tablets': 26, 'ipratropium': 26, 'cannot': 25, 'approximately': 25, 'also': 25, 'erythema': 25, 'symptoms': 25, 'changes': 25, 'safety': 25, '0.5': 25, 'used': 25, '%': 25, 'lisinopril': 25, 'rare': 24, 'see': 24, 'dyspepsia': 24, 'somnolence': 24, 'adult': 24, 'epistaxis': 24, 'weeks': 24, '5%': 24, 'nasal': 24, 'taste': 24, 'sexual': 24, 'bromide': 24, 'frequently': 23, 'report': 23, 'contact': 23, 'pruritus': 23, 'thrombocytopenia': 23, 'possible': 23, 'upper': 23, 'chills': 23, 'ast': 23, 'chest': 23, '(including': 23, 'gabapentin': 23, 'angioedema': 23, 'vision': 22, 'conducted': 22, 'elevated': 22, 'population': 22, 'cases': 22, 'discontinued': 22, 'alt': 22, '14': 22, 'usually': 22, 'fda': 21, 'conditions': 21, 'related': 21, 'causal': 21, 'hyperglycemia': 21, 'urticaria': 21, 'b': 21, 'c': 21, '13': 21, 'commonly': 21, 'digestive': 21, 'premarketing': 21, 'similar': 21, 'effects': 21, 'suspected': 20, '1-800-fda-1088': 20, 'mild': 20, 'sweating': 20, 'special': 20, 'tests': 20, 'metabolic': 20, 'myocardial': 20, 'infarction': 20, 'described': 20, 'months': 20, 'tissue': 20, '15': 20, 'neutropenia': 20, '1.1': 20, 'anorexia': 20, 'depressive': 20, 'creatinine': 19, 'fever': 19, 'syncope': 19, 'among': 19, 'administered': 19, 'seen': 19, 'and/or': 19, 'period': 19, 'transient': 18, 'open-label': 18, 'estimate': 18, 'pulmonary': 18, 'hepatitis': 18, 'muscle': ...

# %%
counts.most_common(20)
# Out:
# [('adverse', 479),
#  ('patients', 458),
#  ('reactions', 355),
#  ('events', 205),
#  ('clinical', 186),
#  ('reported', 182),
#  ('1', 166),
#  ('trials', 162),
#  ('3', 145),
#  ('pain', 141),
#  ('0', 134),
#  ('increased', 126),
#  ('system', 124),
#  ('–', 122),
#  ('mekinist', 116),
#  ('skin', 113),
#  ('2', 108),
#  ('warnings', 105),
#  ('rash', 104),
#  ('6', 102)]

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Hi-
# [nltk_data]     TecH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Hi-
# [nltk_data]     TecH\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn

# %%
def is_medical(word):
    synsets = wn.synsets(word)
    if not synsets:
        return False
    for w in synsets:
        if w.lexname() in ["noun.body","noun.state","noun.substance"]:
            return True
        else:
            return False

# %%
medical_terms = [w for w in counts if is_medical(w)]
print(medical_terms)
# Out:
# ['stinging', 'redness', 'chemical', 'edema', 'body', 'photophobia', 'dryness', 'eye', 'dizziness', 'nausea', 'bleeding', 'ulceration', 'hypertension', 'hyperkalemia', 'skin', 'dyspepsia', 'abdominal', 'pain', 'rash', 'ecchymosis', 'conditions', 'arthritis', 'osteoarthritis', 'complaints', 'diarrhea', 'stomatitis', 'lightheadedness', 'vertigo', 'purpura', 'palpitations', 'thirst', 'flatulence', 'ulcers', 'anemia', 'liver', 'enzymes', 'rashes', 'pancreatitis', 'jaundice', 'melena', 'thrombocytopenia', 'agranulocytosis', 'concentrate', 'disorders', 'pyrexia', 'vasculitis', 'inflammation', 'esophagitis', 'colitis', 'bowel', 'disease', 'hepatitis', 'eosinophilia', 'leucopenia', 'granulocytopenia', 'hyperglycemia', 'hypoglycemia', 'depression', 'abnormalities', 'insomnia', 'malaise', 'myalgia', 'muscle', 'weakness', 'meningitis', 'dysfunction', 'convulsions', 'pneumonitis', 'asthma', 'alopecia', 'urticaria', 'erythema', 'lichen', 'lupus', 'dermatitis', 'porphyria', 'symptoms', 'optic', 'neuritis', 'papilledema', 'nephritis', 'hematuria', 'serum', 'infertility', 'fever', 'infection', 'sepsis', 'tachycardia', 'arrhythmia', 'hypotension', 'infarction', 'mouth', 'gastritis', 'glossitis', 'eructation', 'lymphadenopathy', 'pancytopenia', 'anxiety', 'asthenia', 'confusion', 'paresthesia', 'somnolence', 'hallucinations', 'pneumonia', 'conjunctivitis', 'cystitis', 'dysuria', 'proteinuria', 'ar', 'plastic', 'malignancies', 'hemorrhage', 'cardiomyopathy', 'lung', 'fatigue', 'arthralgia', 'cough', 'solid', 'constipation', 'safety', 'tumors', 'melanoma', 'glioma', 'n', 'pathway', 'epistaxis', 'neutrophil', 'alanine', 'aminotransferase', 'coronary', 'permanent', 'arm', 'e', 'lymphedema', 'tissue', 'paronychia', 'abnormality', 'phosphatase', 'bradycardia', 'infections', 'folliculitis', 'cellulitis', 'neuropathy', 'arrhythmias', 'active', 'brain', 'deficiency', 'status', 'lactate', 'tumor', 'fraction', 'neutropenia', 'hemoglobin', 'hematoma', 'ulcer', 'sarcoidosis', 'lymphopenia', 'hyponatremia', 'blood', 'tension', 'chest', 'cancer', 'hemoptysis', 'bladder', 'contusion', 'dyspnea', 'leukopenia', 'cancers', 'melaena', 'hemothorax', 'bruise', 'petechiae', 'prothrombin', 'retinal', 'uveitis', 'hypersensitivity', 'sodium', 'magnesium', 'infestations', 'hypocalcemia', 'phosphate', 'hypernatremia', 'hypokalemia', 'bilirubin', 'neutrophils', 'platelets', 'lymphocytes', 'cheilitis', 'migraine', 'h', 'neuralgia', 'eczema', 'acne', 'back', 'extremity', 'bone', 'neck', 'jaw', 'injury', 'poisoning', 'potassium', 'calcium', 'glucose', 'leukocytes', 'scar', 'digestive', 'ataxia', 'hypesthesia', 'pharyngitis', 'appendages', 'amblyopia', 'diplopia', 'otitis', 'flu', 'epilepsy', 'throat', 'fracture', 'dysarthria', 'twitching', 'rhinitis', 'coughing', 'abrasion', 'wbc', 'bronchitis', 'anorexia', 'face', 'allergy', 'lassitude', 'hangover', 'angina', 'disorder', 'palpitation', 'fibrillation', 'thrombophlebitis', 'thrombosis', 'embolus', 'hyperlipidemia', 'hypercholesterolemia', 'gastroenteritis', 'hemorrhoids', 'dysphagia', 'blisters', 'tooth', 'gland', 'lip', 'hernia', 'proctitis', 'endocrine', 'goiter', 'epididymitis', 'testicle', 'bruises', 'lymphocytosis', 'lymphoma', 'tendinitis', 'joint', 'swelling', 'costochondritis', 'osteoporosis', 'bursitis', 'cns', 'aphasia', 'hypotonia', 'paresis', 'hemiplegia', 'facial', 'paralysis', 'hallucination', 'agitation', 'paranoia', 'depersonalization', 'dyskinesia', 'encephalopathy', 'nerve', 'palsy', 'apraxia', 'myoclonus', 'neurosis', 'hysteria', 'hiccup', 'laryngitis', 'seborrhea', 'cyst', 'herpes', 'zoster', 'papules', 'leg', 'scalp', 'psoriasis', 'nodules', 'nodule', 'melanosis', 'amenorrhea', 'dysmenorrhea', 'breast', 'kidney', 'leukorrhea', 'anuria', 'glycosuria', 'nephrosis', 'pyuria', 'urgency', 'cataract', 'defect', 'ptosis', 'hordeolum', 'earache', 'tinnitus', 'ear', 'problem', 'retinopathy', 'glaucoma', 'iritis', 'blindness', 'chorioretinitis', 'strabismus', 'labyrinthitis', 'dehydration', 'mononucleosis', 'aura', ' ...

# %%
def clean_text_2(text):
    if not isinstance(text, str):   # skip NaN or non-strings
        return ""
    words = text.split()
    medical_words = [w for w in words if is_medical(w)]
    return " ".join(medical_words)

# Apply safely
new_1["adverse_reactions"] = new_1["adverse_reactions"].apply(clean_text_2)

# %%
new_1.head().dropna()
# Out:
#       generic_name                            manufacturer_name  \
# 0          SILICEA  Rxhomeo Private Limited d.b.a. Rxhomeo, Inc
# 2  POVIDONE-IODINE           Atlantis Consumer Healthcare, Inc.
#
#   adverse_reactions                              indications_and_usage
# 0                    INDICATIONS Condition listed above or as direc...
# 2                    Uses First aid to help prevent infection in mi...

# %%
new_1 = new_1.rename(columns={"indications_and_usage":"drug_use"})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Use TF-IDF to represent each drug's side effects

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(new_1["adverse_reactions"])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute similarity matrix between all drugs
similarity_matrix = cosine_similarity(X, X)

# %%
def recommend_drugs_2(drug_name, top_n=5):
    drug_name = drug_name.strip().lower()  # normalize input
    matches = new_1[new_1["generic_name"].str.lower().str.strip() == drug_name]
    
    if matches.empty:
        return f"Drug '{drug_name}' not found in dataset."
    
    idx = matches.index[0]
    
    sim_scores = list(enumerate(similarity_matrix[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = [i for i in sim_scores if i[0] != idx]
    top_indices = [i[0] for i in sim_scores[:top_n]]
    
    return new_1.iloc[top_indices][["generic_name", "adverse_reactions", "drug_use"]]

# %%
new_1.head(50)
# Out:
#                                          generic_name  \
# 0                                             SILICEA
# 1                                                 NaN
# 2                                     POVIDONE-IODINE
# 3                                                 NaN
# 4                                                 NaN
# 5                                            NAPROXEN
# 6                                                 NaN
# 7                               BENZALKONIUM CHLORIDE
# 8                                                 NaN
# 9                                                 NaN
# 10                                     SALICYLIC ACID
# 11                          CUPRUM ACETICUM NICOTIANA
# 12                                         TRAMETINIB
# 13                                                NaN
# 14                                        GLIMEPIRIDE
# 15                                                NaN
# 16                                      METHOCARBAMOL
# 17                                     HYDROCORTISONE
# 18                        LEVOTHYROXINE, LIOTHYRONINE
# 19                                        VARENICLINE
# 20                                                NaN
# 21                                                NaN
# 22  HELIANTHEMUM NUMMULARIUM FLOWER, CLEMATIS VITA...
# 23                                      ACETAMINOPHEN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                           GLYCERIN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                             BENZOCAINE, RESORCINOL
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                             ALUMINUM CHLOROHYDRATE
# 41                         BETAMETHASONE DIPROPIONATE
# 42                                                NaN
# 43                                                NaN
# 44                                    POVIDONE-IODINE
# 45                                    CALCIUM ACETATE
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                           SACUBITRIL AND VALSARTAN
#
#                               manufacturer_name  \
# 0   Rxhomeo Private Limited d.b.a. Rxhomeo, Inc
# 1                                           NaN
# 2            Atlantis Consumer Healthcare, Inc.
# 3                                           NaN
# 4                                           NaN
# 5                      A-S Medication Solutions
# 6                                           NaN
# 7                                  Walmart Inc.
# 8                                           NaN
# 9                                           NaN
# 10                                 Walmart Inc.
# 11                          Uriel Pharmacy Inc.
# 12         Novartis Pharmaceuticals Corporation
# 13                                          NaN
# 14                    American Health Packaging
# 15                                          NaN
# 16                             Proficient Rx LP
# 17                                 Meijer, Inc.
# 18                  Acella Pharmaceuticals, LLC
# 19                     Aurobindo Pharma Limited
# 20                                          NaN
# 21                                          NaN
# 22                        Nelson Bach USA, Ltd.
# 23                   Valu Merchandisers Company
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                          OASIS Medical, Inc.
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                     FOURSTAR GROUP USA, INC.
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN
# 36                                          NaN
# 37                                          NaN
# 38                                          NaN
# 39                                          NaN
# 40                             Sodalis USA, LLC
# 41          Sun Pharmaceutical Industries, Inc.
# 42                                          NaN
# 43                                          NaN
# 44         Lights Medical Manufacture Co., Ltd.
# 45                              Cipla USA Inc.,
# 46                                          NaN
# 47                                          NaN
# 48                                          NaN
# 49         Novartis Pharmaceuticals Corporation
#
#                                     adverse_reactions  \
# 0
# 1
# 2
# 3
# 4                  chemical body eye dizziness nausea
# 5   Hypertension Edema Hyperkalemia Skin abdominal...
# 6
# 7
# 8
# 9
# 10                                         AR PLASTIC
# 11
# 12  Malignancies Hemorrhage Colitis Cardiomyopathy...
# 13  Neuralgia at symptoms at neuralgia Neuralgia a...
# 14  Hypoglycemia anemia dizziness at at be diabete...
# 15  infections infections diarrhea nausea dyspepsi...
# 16  Body as thrombophlebitis Digestive jaundice na...
# 17
# 18                                    hyperthyroidism
# 19  Seizures Injury Angioedema Hypersensitivity Sk...
# 20
# 21
# 22
# 23
# 24
# 25
# 26  Bleeding purpura at at conditions be safety Bl...
# 27
# 28
# 29  formulations acetate acetate abdominal symptom...
# 30  sulfate solution irritation at hypersensitivit...
# 31  at sedation dizziness weakness sleep symptoms ...
# 32
# 33
# 34  bromide solution cold bromide solution bromide...
# 35
# 36  colitis colitis abdominal nausea colitis sympt...
# 37
# 38
# 39
# 40
# 41  skin at at be at skin atrophy corticosteroids ...
# 42
# 43  abdominal ulcers liver bleeding complaints bod...
# 44
# 45  Hypercalcemia nausea nausea calcium acetate at...
# 46
# 47
# 48
# 49  Angioedema Hypotension Hyperkalemia at at be a...
#
#                                              drug_use
# 0   INDICATIONS Condition listed above or as direc...
# 1   Uses Multi-purpose mineral powder provides bro...
# 2   Uses First aid to help prevent infection in mi...
# 3           INDICATIONS Indications: MEZEREUM Itching
# 4   INDICATIONS AND USAGE Ofloxacin ophthalmic sol...
# 5   1 INDICATIONS AND USAGE Naproxen tablets and n...
# 6   Use surgical hand scrub: significantly reduces...
# 7   Use For handwashing to decrease bacteria on th...
# 8   Directions: Acne Clearing Cleanser Acne Cleari...
# 9   For the temporary relief of nasal decongestiom...
# 10                     Uses for the treatment of acne
# 11                     Directions: FOR ORAL USE ONLY.
# 12  1 INDICATIONS AND USAGE MEKINIST is a kinase i...
# 13  INDICATIONS & USAGE Gabapentin Tablets, USP Re...
# 14  1 INDICATIONS AND USAGE Glimepiride tablets ar...
# 15  INDICATIONS AND USAGE Clarithromycin tablets a...
# 16  INDICATIONS AND USAGE Methocarbamol tablets, U...
# 17  Uses • temporarily relieves itching associated...
# 18  INDICATIONS AND USAGE NP Thyroid ® tablets (th...
# 19  1 INDICATIONS AND USAGE Varenicline tablets ar...
# 20  Use for the preparation of the patient's skin ...
# 21  Uses • temporarily relieves minor aches and pa...
# 22  Use for relief of occasional sleeplessness cau...
# 23  Uses temporarily relieves minor aches and pain...
# 24  Uses • helps prevent sunburn • higher SPF give...
# 25  Uses temporarily relieves the minor aches and ...
# 26  1 INDICATIONS AND USAGE Plavix is a P2Y 12 pla...
# 27  Uses helps loosen phlegm (mucus) and thin bron...
# 28  Uses For the temporary relief of burning and i...
# 29  INDICATIONS AND USAGE: Central Diabetes Insipi...
# 30  INDICATIONS AND USAGE Polymyxin B sulfate and ...
# 31  INDICATIONS AND USAGE Lorazepam is indicated f...
# 32                  Uses temporarily relieves itching
# 33  INDICATIONS & USAGE SECTION Cell Salt; Hemorrh...
# 34  INDICATIONS & USAGE Ipratropium bromide nasal ...
# 35              Indications To optimize body minerals
# 36  INDICATIONS AND USAGE Clindamycin Injection, U...
# 37  USE: hand sanitizer to help reduce bacteria on...
# 38                          Directions: FOR ORAL USE.
# 39  Uses: Homeopathic medicine for temporary relie...
# 40                       Use reduces underarm wetness
# 41  1 INDICATIONS AND USAGE Betamethasone dipropio...
# 42  Use to decrease bacteria on the skin that coul...
# 43  INDICATIONS AND USAGE Carefully consider the p...
# 44                   Use: Antiseptic skin preparation
# 45  1 INDICATIONS AND USAGE Calcium acetate is a p...
# 46                    Uses Uses: Firming & Nourishing
# 47  Purpose: To help alleviate the symptoms of grief.
# 48  USES This homeopathic medicine helps relieve s...
# 49  1 INDICATIONS AND USAGE ENTRESTO is a combinat...

# %%
recommend_drugs_2("NAPROXEN", top_n=5)
# Out:
#    generic_name                                  adverse_reactions  \
# 60     ETODOLAC  abdominal ulcers liver bleeding complaints bod...
# 43          NaN  abdominal ulcers liver bleeding complaints bod...
# 26          NaN  Bleeding purpura at at conditions be safety Bl...
# 36          NaN  colitis colitis abdominal nausea colitis sympt...
# 72          NaN  be abnormalities angina angina as as edema nau...
#
#                                              drug_use
# 60  INDICATIONS AND USAGE Carefully consider the p...
# 43  INDICATIONS AND USAGE Carefully consider the p...
# 26  1 INDICATIONS AND USAGE Plavix is a P2Y 12 pla...
# 36  INDICATIONS AND USAGE Clindamycin Injection, U...
# 72  INDICATIONS AND USAGE Diltiazem hydrochloride ...

# %%
new_1["generic_name"].fillna("unknown",inplace=True)

# %%
recommend_drugs_2("NAPROXEN", top_n=5)
# Out:
#    generic_name                                  adverse_reactions  \
# 60     ETODOLAC  abdominal ulcers liver bleeding complaints bod...
# 43      unknown  abdominal ulcers liver bleeding complaints bod...
# 26      unknown  Bleeding purpura at at conditions be safety Bl...
# 36      unknown  colitis colitis abdominal nausea colitis sympt...
# 72      unknown  be abnormalities angina angina as as edema nau...
#
#                                              drug_use
# 60  INDICATIONS AND USAGE Carefully consider the p...
# 43  INDICATIONS AND USAGE Carefully consider the p...
# 26  1 INDICATIONS AND USAGE Plavix is a P2Y 12 pla...
# 36  INDICATIONS AND USAGE Clindamycin Injection, U...
# 72  INDICATIONS AND USAGE Diltiazem hydrochloride ...
